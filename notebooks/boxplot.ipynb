# %%
# A 'magic' command to display plots inline
# %matplotlib inline

import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('data/streamflow_annual_rcp45_SAC_B.csv')
df.columns
# Out:
# Index(['model', 'year', 'value'], dtype='object')

# %%
sns.boxplot(y="value", x="model", data=df)

# %%
sns.stripplot(y="model", x="value", data=df, jitter=True)
